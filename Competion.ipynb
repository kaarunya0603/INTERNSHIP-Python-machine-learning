# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            73 non-null     object
#  1   Opponent        73 non-null     object
#  2   Team Score      72 non-null     float64
#  3   Opponent Score  72 non-null     float64
#  4   Result          73 non-null     object
#  5   Venue           73 non-null     object
#  6   Competition     73 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.1+ KB

# %%
df.head(3)
# Out:
#     Date           Opponent  Team Score  Opponent Score Result    Venue  \
# 0  ~1957  Northern Rhodesia         0.0             5.0   Loss  Unknown
# 1  ~1962              Ghana         0.0            12.0   Loss  Unknown
# 2  ~1968           Botswana         8.0             1.0    Win  Unknown
#
#                       Competition
# 0  Friendly (First International)
# 1                        Friendly
# 2                        Friendly

# %%
df.iloc[2]
# Out:
# Date                 ~1968
# Opponent          Botswana
# Team Score             8.0
# Opponent Score         1.0
# Result                 Win
# Venue              Unknown
# Competition       Friendly
# Name: 2, dtype: object

# %%
df[:3]
# Out:
#     Date           Opponent  Team Score  Opponent Score Result    Venue  \
# 0  ~1957  Northern Rhodesia         0.0             5.0   Loss  Unknown
# 1  ~1962              Ghana         0.0            12.0   Loss  Unknown
# 2  ~1968           Botswana         8.0             1.0    Win  Unknown
#
#                       Competition
# 0  Friendly (First International)
# 1                        Friendly
# 2                        Friendly

# %%
df[3:6]
# Out:
#          Date      Opponent  Team Score  Opponent Score Result Venue  \
# 3  02-06-1996  South Africa         0.0             3.0   Loss  Away
# 4  07-07-1996        Zambia         1.0             1.0   Draw  Home
# 5  08-01-2010       Algeria         0.0             3.0   Loss  Away
#
#               Competition
# 3     World Cup Qualifier
# 4                Friendly
# 5  AFCON 2010 Group Stage

# %%
df['Opponent'].head(3)
# Out:
# 0    Northern Rhodesia
# 1                Ghana
# 2             Botswana
# Name: Opponent, dtype: object

# %%
df.Opponent.head(3)
# Out:
# 0    Northern Rhodesia
# 1                Ghana
# 2             Botswana
# Name: Opponent, dtype: object

# %%
df.columns = [col.replace(' ', '_').lower() for col in df.columns]
print(df.columns)
# Out:
# Index(['date', 'opponent', 'team_score', 'opponent_score', 'result', 'venue',
#        'competition'],
#       dtype='object')

# %%
df[df.opponent== 'Ghana']
# Out:
#           date opponent  team_score  opponent_score result    venue  \
# 1        ~1962    Ghana         0.0            12.0   Loss  Unknown
# 14  08-09-2012    Ghana         0.0             1.0   Loss     Away
# 15  13-10-2012    Ghana         0.0             1.0   Loss     Home
# 21  07-10-2016    Ghana         0.0             0.0   Draw     Away
#
#             competition
# 1              Friendly
# 14      AFCON Qualifier
# 15      AFCON Qualifier
# 21  World Cup Qualifier

# %%
df[df['competition'].str.split().apply(lambda x: len(x) == 3)].head(3)
# Out:
#           date           opponent  team_score  opponent_score result    venue  \
# 0        ~1957  Northern Rhodesia         0.0             5.0   Loss  Unknown
# 3   02-06-1996       South Africa         0.0             3.0   Loss     Away
# 12  02-06-2012              Kenya         0.0             0.0   Draw     Away
#
#                        competition
# 0   Friendly (First International)
# 3              World Cup Qualifier
# 12             World Cup Qualifier

# %%
df[df.result.isin(['Loss', 'Win'])].head(10)
# Out:
#           date           opponent  team_score  opponent_score result    venue  \
# 0        ~1957  Northern Rhodesia         0.0             5.0   Loss  Unknown
# 1        ~1962              Ghana         0.0            12.0   Loss  Unknown
# 2        ~1968           Botswana         8.0             1.0    Win  Unknown
# 3   02-06-1996       South Africa         0.0             3.0   Loss     Away
# 5   08-01-2010            Algeria         0.0             3.0   Loss     Away
# 6   11-01-2010             Angola         0.0             2.0   Loss     Away
# 7   14-01-2010               Mali         1.0             3.0   Loss     Away
# 9   09-10-2010               Chad         6.0             2.0    Win     Home
# 10  17-11-2010             Rwanda         2.0             1.0    Win     Home
# 13  09-06-2012            Nigeria         0.0             2.0   Loss     Home
#
#                        competition
# 0   Friendly (First International)
# 1                         Friendly
# ...

# %%
df.describe()
# Out:
#        team_score  opponent_score
# count   72.000000       72.000000
# mean     0.833333        1.569444
# std      1.342690        1.758892
# min      0.000000        0.000000
# 25%      0.000000        0.000000
# 50%      0.000000        1.000000
# 75%      1.000000        2.000000
# max      8.000000       12.000000
