# %%
import pandas as pd

# %%
import numpy as np

# %%
d = { 'A':[1,2,np.nan] ,       #1 value missing in col1
      'B':[5,np.nan,np.nan],    #2 values missing in col2  
      'C':[1,2,3] }             #no missing values in col 3

# %%
df=pd.DataFrame(d)   # creates table structure

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis=0)  # remove rows that contain any missing values (NaN).
                   # (axis=0) tells pandas to drop rows (instead of columns)
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.dropna(axis =1)  #removes the column that missing nan values
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna??
# Out:
# Signature:
# df.dropna(
#     *,
#     axis: 'Axis' = 0,
#     how: 'AnyAll | lib.NoDefault' = <no_default>,
#     thresh: 'int | lib.NoDefault' = <no_default>,
#     subset: 'IndexLabel | None' = None,
#     inplace: 'bool' = False,
#     ignore_index: 'bool' = False,
# ) -> 'DataFrame | None'
# Source:
#     def dropna(
#         self,
#         *,
#         axis: Axis = 0,
#         how: AnyAll | lib.NoDefault = lib.no_default,
#         thresh: int | lib.NoDefault = lib.no_default,
#         subset: IndexLabel | None = None,
#         inplace: bool = False,
#         ignore_index: bool = False,
#     ) -> DataFrame | None:
#         """
#         Remove missing values.
#
#         See the :ref:`User Guide <missing_data>` for more on which values are
#         considered missing, and how to work with missing data.
#
#         Parameters
#         ----------
#         axis : {0 or 'index', 1 or 'columns'}, default 0
# ...

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value = 'NA') #fill missing values DataFrame with a specific value.
                        # used to replace missing values (NaN) with meaningful data
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0   NA  2
# 2   NA   NA  3

# %%
df=pd.DataFrame(d)

# %%
a = df['A'].fillna(value = df['A'].mean()) #Sum = 1.0 + 2.0 = 3.0

                                            #Count = 2

                                            #Mean = 3.0 / 2 = 1.5

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
data={ 'Company':['Google','Google','MSFT','FB','FB','IBM'],
       'person':['Sam','Nihad','Any','Van','Rakib','Ovi'],
       'Sales': [200,120,340,124,243,350]
      }

# %%
df =pd.DataFrame(data)

# %%
df
# Out:
#   Company person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
byComp = df.groupby('Company') # groups the DataFrame rows based on unique values in column 
                               # ,for further analysis like sum, mean, or count.

# %%
byComp.sum() #calculates the sum of numerical columns for each group in the column
# Out:
#            person  Sales
# Company
# FB       VanRakib    367
# Google   SamNihad    320
# IBM           Ovi    350
# MSFT          Any    340

# %% [markdown]
# df

# %%
df.groupby('Company').count() # returns number of non-missing values in each column 
                              # for each group in the column.
# Out:
#          person  Sales
# Company
# FB            2      2
# Google        2      2
# IBM           1      1
# MSFT          1      1

# %%
df
# Out:
#   Company person  Sales
# 0  Google    Sam    200
# 1  Google  Nihad    120
# 2    MSFT    Any    340
# 3      FB    Van    124
# 4      FB  Rakib    243
# 5     IBM    Ovi    350

# %%
df.groupby('Company').describe() # generates descriptive statistics (like count, mean, std, min, max, etc.) 
                                 # for each numerical column within each 'Company' group.
# Out:
#         Sales
#         count   mean        std    min     25%    50%     75%    max
# Company
# FB        2.0  183.5  84.145707  124.0  153.75  183.5  213.25  243.0
# Google    2.0  160.0  56.568542  120.0  140.00  160.0  180.00  200.0
# IBM       1.0  350.0        NaN  350.0  350.00  350.0  350.00  350.0
# MSFT      1.0  340.0        NaN  340.0  340.00  340.0  340.00  340.0

# %%
#Concatenating
df1 = pd.DataFrame(np.random.randint(1, 20, size = (4, 3)), [1,2,3,4], ['W', 'X', 'Y'])
    # This line creates a new DataFrame df1 with:
     # Random integers between 1 and 19 
     # A size of 4 rows and 3 columns,
     # Row indices labeled [1, 2, 3, 4],
     # Column names labeled ['W', 'X', 'Y'].

# %%
df2 = pd.DataFrame(np.random.randint(20,40, size = (4, 3)), [5,6,7,8], ['W', 'X', 'Y'])

# %%
df3 = pd.DataFrame(np.random.randint(40,60, size = (4, 3)), [9,10,11,12], ['W', 'X', 'Y'])

# %%
df1
# Out:
#     W   X   Y
# 1   1  14  18
# 2  13  15  16
# 3   1  17  19
# 4  19   7   4

# %%
df2
# Out:
#     W   X   Y
# 5  39  37  25
# 6  27  25  23
# 7  31  20  36
# 8  28  29  21

# %%
df3
# Out:
#      W   X   Y
# 9   53  42  59
# 10  54  53  59
# 11  47  51  41
# 12  52  48  59

# %%
frame = [df1, df2, df3] # combine all rows from df1, df2, and df3 into a single DataFrame

# %%
pd.concat(frame, axis = 1)
# Out:
#        W     X     Y     W     X     Y     W     X     Y
# 1    1.0  14.0  18.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2   13.0  15.0  16.0   NaN   NaN   NaN   NaN   NaN   NaN
# 3    1.0  17.0  19.0   NaN   NaN   NaN   NaN   NaN   NaN
# 4   19.0   7.0   4.0   NaN   NaN   NaN   NaN   NaN   NaN
# 5    NaN   NaN   NaN  39.0  37.0  25.0   NaN   NaN   NaN
# 6    NaN   NaN   NaN  27.0  25.0  23.0   NaN   NaN   NaN
# 7    NaN   NaN   NaN  31.0  20.0  36.0   NaN   NaN   NaN
# 8    NaN   NaN   NaN  28.0  29.0  21.0   NaN   NaN   NaN
# 9    NaN   NaN   NaN   NaN   NaN   NaN  53.0  42.0  59.0
# 10   NaN   NaN   NaN   NaN   NaN   NaN  54.0  53.0  59.0
# 11   NaN   NaN   NaN   NaN   NaN   NaN  47.0  51.0  41.0
# 12   NaN   NaN   NaN   NaN   NaN   NaN  52.0  48.0  59.0

# %%
#Merging
left = {
    'key':['k0','k1','k2','k3'],
    'A':[10,20,30,40],
    'B':[1,2,3,4]
}

# %%
right = {
    'key':['k0','k1','k2','k3'],
    'C':[100,200,300,400],
    'D':[11,12,13,14]
}

# %%
left = pd.DataFrame(left)

# %%
right = pd.DataFrame(right)

# %%
left
# Out:
#   key   A  B
# 0  k0  10  1
# 1  k1  20  2
# 2  k2  30  3
# 3  k3  40  4

# %%
right
# Out:
#   key    C   D
# 0  k0  100  11
# 1  k1  200  12
# 2  k2  300  13
# 3  k3  400  14

# %%
pd.merge(left, right, on='key')
# Out:
#   key   A  B    C   D
# 0  k0  10  1  100  11
# 1  k1  20  2  200  12
# 2  k2  30  3  300  13
# 3  k3  40  4  400  14

# %%
pd.merge??
# Out:
# Signature:
# pd.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | None' = None,
#     left_on: 'IndexLabel | None' = None,
#     right_on: 'IndexLabel | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# When performing a cross merge, no column specifications to merge on are
# allowed.
#
# ...

# %%
left = {
    'A':['A0','A1','A2'],
    'B':['B0','B1','B2']
}

# %%
right = {
    'C':['C0','C2','C3'],
    'D':['D0','D2','D3']
}

# %%
left = pd.DataFrame(left, index = ['k0','k1','k2'])

# %%
right = pd.DataFrame(right, index = ['k0','k2','k3'])

# %%
left
# Out:
#      A   B
# k0  A0  B0
# k1  A1  B1
# k2  A2  B2

# %%
right
# Out:
#      C   D
# k0  C0  D0
# k2  C2  D2
# k3  C3  D3

# %%
left.join(right, how = 'inner')
# Out:
#      A   B   C   D
# k0  A0  B0  C0  D0
# k2  A2  B2  C2  D2

# %%
left.join??
# Out:
# Signature:
# left.join(
#     other: 'DataFrame | Series | Iterable[DataFrame | Series]',
#     on: 'IndexLabel | None' = None,
#     how: 'MergeHow' = 'left',
#     lsuffix: 'str' = '',
#     rsuffix: 'str' = '',
#     sort: 'bool' = False,
#     validate: 'JoinValidate | None' = None,
# ) -> 'DataFrame'
# Source:
#     def join(
#         self,
#         other: DataFrame | Series | Iterable[DataFrame | Series],
#         on: IndexLabel | None = None,
#         how: MergeHow = "left",
#         lsuffix: str = "",
#         rsuffix: str = "",
#         sort: bool = False,
#         validate: JoinValidate | None = None,
#     ) -> DataFrame:
#         """
#         Join columns of another DataFrame.
#
#         Join columns with `other` DataFrame either on index or on a key
#         column. Efficiently join multiple DataFrame objects by index at once by
#         passing a list.
#
#         Parameters
#         ----------
# ...

# %%
#OPERATIONS

# %%
df = pd.DataFrame({
    'col1':[444,555,666,444],
    'col2':[1,2,3,4],
    'col3':['abc','def','ghi','xyz']
})

# %%
df
# Out:
#    col1  col2 col3
# 0   444     1  abc
# 1   555     2  def
# 2   666     3  ghi
# 3   444     4  xyz

# %%
df['col1'].unique()
# Out:
# array([444, 555, 666], dtype=int64)

# %%
df['col1'].nunique()
# Out:
# 3

# %%
df['col1'].value_counts()
# Out:
# col1
# 444    2
# 555    1
# 666    1
# Name: count, dtype: int64

# %%
def times2(x):
    return 2*x

# %%
df['col2'].apply(times2)
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# Name: col2, dtype: int64

# %%
df['col2'].apply(lambda x: x**2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# Name: col2, dtype: int64

# %%
#READING FILE

# %%
df = pd.read_excel('SampleData.xlsx', sheet_name = 'SalesOrders')

# %%
df
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total
# 0  2019-01-06     East     Jones   Pencil     95       1.99   189.05
# 1  2019-01-23  Central    Kivell   Binder     50      19.99   999.50
# 2  2019-02-09  Central   Jardine   Pencil     36       4.99   179.64
# 3  2019-02-26  Central      Gill      Pen     27      19.99   539.73
# 4  2019-03-15     West   Sorvino   Pencil     56       2.99   167.44
# 5  2019-04-01     East     Jones   Binder     60       4.99   299.40
# 6  2019-04-18  Central   Andrews   Pencil     75       1.99   149.25
# 7  2019-05-05  Central   Jardine   Pencil     90       4.99   449.10
# 8  2019-05-22     West  Thompson   Pencil     32       1.99    63.68
# 9  2019-06-08     East     Jones   Binder     60       8.99   539.40
# 10 2019-06-25  Central    Morgan   Pencil     90       4.99   449.10
# 11 2019-07-12     East    Howard   Binder     29       1.99    57.71
# 12 2019-07-29     East    Parent   Binder     81      19.99  1619.19
# ...

# %%
df.tail()
# Out:
#     OrderDate   Region       Rep    Item  Units  Unit Cost    Total
# 38 2020-10-14     West  Thompson  Binder     57      19.99  1139.43
# 39 2020-10-31  Central   Andrews  Pencil     14       1.29    18.06
# 40 2020-11-17  Central   Jardine  Binder     11       4.99    54.89
# 41 2020-12-04  Central   Jardine  Binder     94      19.99  1879.06
# 42 2020-12-21  Central   Andrews  Binder     28       4.99   139.72

# %%
df.columns
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total'], dtype='object')

# %%
df.columns.to_list()
# Out:
# ['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderDate  43 non-null     datetime64[ns]
#  1   Region     43 non-null     object
#  2   Rep        43 non-null     object
#  3   Item       43 non-null     object
#  4   Units      43 non-null     int64
#  5   Unit Cost  43 non-null     float64
#  6   Total      43 non-null     float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB

# %%
df.nunique()
# Out:
# OrderDate    43
# Region        3
# Rep          11
# Item          5
# Units        37
# Unit Cost    12
# Total        41
# dtype: int64

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
df['20% Dis'] = df['Total'].apply(lambda x: x*(20/100))

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total  20% Dis
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05   37.810
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50  199.900
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64   35.928
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73  107.946
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44   33.488

# %%
df['Payment'] = df['Total'] - df['20% Dis']

# %%
df.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total  20% Dis  \
# 0 2019-01-06     East    Jones  Pencil     95       1.99  189.05   37.810
# 1 2019-01-23  Central   Kivell  Binder     50      19.99  999.50  199.900
# 2 2019-02-09  Central  Jardine  Pencil     36       4.99  179.64   35.928
# 3 2019-02-26  Central     Gill     Pen     27      19.99  539.73  107.946
# 4 2019-03-15     West  Sorvino  Pencil     56       2.99  167.44   33.488
#
#    Payment
# 0  151.240
# 1  799.600
# 2  143.712
# 3  431.784
# 4  133.952

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (12,6))
plt.plot(df['OrderDate'], df['Total'])
plt.show()
